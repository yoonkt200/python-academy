# %% [markdown]
# ## 1. 변수 선언하기

# %% [markdown]
# ![variable](../../img/variable1.png)

# %% [markdown]
# ![variable](../../img/variable2.png)

# %% [markdown]
# ### 1) 숫자형 변수

# %%
a = 1992
b = 613
c = -825
d = 0

# %%
e = 8.11
f = -19.94
g = 9.18E10
h = 9.18e-10

# %% [markdown]
# ----
# ### 2) 숫자형 변수를 활용한 계산 프로그래밍

# %%
# 더하기
a+b
# Out:
# 2605

# %%
# 더하기
c+g
# Out:
# 91799999175.0

# %%
# 빼기
f-h
# Out:
# -19.940000000918

# %%
# 곱하기
c*h
# Out:
# -7.5735e-07

# %%
# 나누기
a / h
# Out:
# 2169934640522.8757

# %%
# 제곱 연산자
b ** 3
# Out:
# 230346397

# %%
# 몫 반환 연산자
a // 5
# Out:
# 398

# %%
# 나머지 반환 연산자
a % 5
# Out:
# 2

# %% [markdown]
# -----
# ### 3) 문자열 변수

# %%
a = "Hello World!"
b = '19920613'

# %%
c = "Python's String"

# %%
d = "Python\"s String"

# %%
e = """
My Favorite 
is Python
"""

# %% [markdown]
# -----
# ### 4) 문자열 변수를 활용한 프로그래밍

# %%
a+b
# Out:
# 'Hello World!19920613'

# %%
print(a,b)
# Out:
# Hello World! 19920613

# %%
"".join([a,b])
# Out:
# 'Hello World!19920613'

# %%
a * 5
# Out:
# 'Hello World!Hello World!Hello World!Hello World!Hello World!'

# %%
len(d)
# Out:
# 15

# %%
a[0]
# Out:
# 'H'

# %%
a[3:5]
# Out:
# 'lo'

# %%
a[-1]
# Out:
# '!'

# %%
a[:-2]
# Out:
# 'Hello Worl'

# %%
a[3:-3]
# Out:
# 'lo Wor'

# %% [markdown]
# -----
# ### 5) 문자열 관련 응용 함수

# %%
a.split(" ")
# Out:
# ['Hello', 'World!']

# %%
b = a.split(" ")
b[0]
# Out:
# 'Hello'

# %%
a.replace("Hello", "Destroy")
# Out:
# 'Destroy World!'

# %%
a.count("l")
# Out:
# 3
