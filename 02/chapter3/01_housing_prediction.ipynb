# %% [markdown]
# ## 2. 데이터의 기본 정보 파악하기
# ### 1) 데이터의 크기 및 기본 정보

# %%
# -*- coding: utf-8 -*-

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Data Source : http://lib.stat.cmu.edu/datasets/boston_corrected.txt

data_dir = '../../dataset/BostonHousing.csv'
housing = pd.read_csv(data_dir)

# %% [markdown]
# -----
# #### BostonHousing.csv
# ##### [데이터셋의 피처]
# - TOWN : 지역 이름
# - LON, LAT : 위도, 경도 정보
# - CMEDV : 해당 지역의 집값(중간값)
# - CRIM : 지역 범죄율
# - ZN : 주택지 비율
# - INDUS : 상업적 비즈니스에 활용되지 않는 농지 면적
# - CHAS : 경계선에 강에 있는지 여부
# - NOX : 산화 질소 농도
# - RM : 자택당 평균 방 갯수
# - AGE : 1940 년 이전에 건설된 비율
# - DIS : 5 개의 보스턴 고용 센터와의 거리에 다른 가중치 부여
# - RAD : radial 고속도로와의 접근성 지수
# - TAX : 10000달러당 재산세
# - PTRATIO : 지역별 학생-교사 비율
# - B : 지역의 흑인 지수 (1000(B - 0.63)^2), B는 흑인의 비율.
# - LSTAT : 빈곤층의 비율

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TOWN     506 non-null    object
#  1   LON      506 non-null    float64
#  2   LAT      506 non-null    float64
#  3   CMEDV    506 non-null    float64
#  4   CRIM     506 non-null    float64
#  5   ZN       506 non-null    float64
#  6   INDUS    506 non-null    float64
#  7   CHAS     506 non-null    int64
#  8   NOX      506 non-null    float64
#  9   RM       506 non-null    float64
#  10  AGE      506 non-null    float64
#  11  DIS      506 non-null    float64
#  12  RAD      506 non-null    int64
#  13  TAX      506 non-null    int64
#  14  PTRATIO  506 non-null    float64
#  15  B        506 non-null    float64
#  16  LSTAT    506 non-null    float64
# dtypes: float64(13), int64(3), object(1)
# memory usage: 67.3+ KB

# %% [markdown]
# ----
# ### 2) 회귀 분석의 종속 변수 분포 살펴보기

# %%
housing['CMEDV'].describe()
# Out:
# count    506.000000
# mean      22.528854
# std        9.182176
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: CMEDV, dtype: float64

# %%
housing['CMEDV'].hist(bins=50) # 보스턴 집값의 분포
# Out:
# <AxesSubplot:>

# %%
housing.boxplot(column=['CMEDV']) # 보스턴 집값의 Boxplot
# Out:
# <AxesSubplot:>

# %% [markdown]
# ----
# ### 3) 회귀 분석에 사용할 변수의 분포 살펴보기

# %%
housing_features_df = housing[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 
                            'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'CMEDV']]
housing_features_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  CMEDV
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
# 피처 각각에 대한 histogram
def plot_hist_each_column(df):
    plt.rcParams['figure.figsize'] = [20, 16]
    fig = plt.figure(1)
    for i in range(len(df.columns)):
        ax = fig.add_subplot(4, 4, i+1)
        plt.hist(df[df.columns[i]], bins=50)
        ax.set_title(df.columns[i])
    plt.show()

# %%
plot_hist_each_column(housing_features_df)

# %% [markdown]
# ----
# ## 3. 데이터 전처리
# ### 1) 피처 스케일링

# %%
pd.options.mode.chained_assignment = None

# %%
# 피처 각각에 대한 scaling을 수행
def standard_scaling(df, scale_columns):
    for col in scale_columns:
        series_mean = df[col].mean()
        series_std = df[col].std()
        df[col] = df[col].apply(lambda x: (x-series_mean)/series_std)
    return df

# %%
scale_columns = ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 
                 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
scaled_housing_df = standard_scaling(housing_features_df, scale_columns)

# %%
scaled_housing_df = scaled_housing_df.rename(columns={'CMEDV': 'y'})
scaled_housing_df.head(10)
# Out:
#        CRIM        ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0 -0.419367  0.284548 -1.286636     0 -0.144075  0.413263 -0.119895  0.140075
# 1 -0.416927 -0.487240 -0.592794     0 -0.739530  0.194082  0.366803  0.556609
# 2 -0.416929 -0.487240 -0.592794     0 -0.739530  1.281446 -0.265549  0.556609
# 3 -0.416338 -0.487240 -1.305586     0 -0.834458  1.015298 -0.809088  1.076671
# 4 -0.412074 -0.487240 -1.305586     0 -0.834458  1.227362 -0.510674  1.076671
# 5 -0.416631 -0.487240 -1.305586     0 -0.834458  0.206892 -0.350810  1.076671
# 6 -0.409837  0.048724 -0.476182     0 -0.264892 -0.388027 -0.070159  0.838414
# 7 -0.403297  0.048724 -0.476182     0 -0.264892 -0.160307  0.977841  1.023625
# 8 -0.395543  0.048724 -0.476182     0 -0.264892 -0.930285  1.116390  1.086122
# 9 -0.400333  0.048724 -0.476182     0 -0.264892 -0.399413  0.615481  1.328320
#
#         RAD       TAX   PTRATIO         B     LSTAT     y
# 0 -0.981871 -0.665949 -1.457558  0.440616 -1.074499  24.0
# 1 -0.867024 -0.986353 -0.302794  0.440616 -0.491953  21.6
# 2 -0.867024 -0.986353 -0.302794  0.396035 -1.207532  34.7
# 3 -0.752178 -1.105022  0.112920  0.415751 -1.360171  33.4
# 4 -0.752178 -1.105022  0.112920  0.440616 -1.025487  36.2
# 5 -0.752178 -1.105022  0.112920  0.410165 -1.042291  28.7
# 6 -0.522484 -0.576948 -1.503749  0.426376 -0.031237  22.9
# 7 -0.522484 -0.576948 -1.503749  0.440616  0.909800  22.1
# 8 -0.522484 -0.576948 -1.503749  0.328123  2.419379  16.5
# 9 -0.522484 -0.576948 -1.503749  0.329000  0.622728  18.9

# %% [markdown]
# ----
# ### 2) 변수들의 상관 관계 분석

# %%
# 변수간의 상관계수 행렬 구하기
cols = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 
        'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
corr = scaled_housing_df[cols].corr(method = 'pearson')
corr
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000

# %%
import seaborn as sns

# corr 행렬 히트맵 시각화
cols_view = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 
             'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
sns.set(font_scale=1.5)
hm = sns.heatmap(corr.values,
            cbar=True,
            annot=True, 
            square=True,
            fmt='.2f',
            annot_kws={'size': 15},
            yticklabels=cols_view,
            xticklabels=cols_view)

plt.tight_layout()
plt.show()

# %% [markdown]
# ----
# ## 4. 회귀 분석 실습
# ### 1) 데이터셋 분리와 모델 학습

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

X = scaled_housing_df[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 
                       'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = scaled_housing_df['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=33)

# %%
lr = linear_model.LinearRegression()
model = lr.fit(X_train, y_train)

# %% [markdown]
# ----
# ### 2) 회귀 분석 결과 살펴보기

# %%
print(lr.coef_) # 각 변수별 계수 출력
# Out:
# [-0.95643634  1.18808119  0.22326069  3.02115825 -1.78577413  2.84272496
#  -0.05562082 -3.28731689  2.84761095 -2.33972039 -1.77991349  0.79851917
#  -4.17795131]

# %%
plt.rcParams['figure.figsize'] = [20, 16]

coefs = lr.coef_.tolist()
coefs_series = pd.Series(coefs)

x_labels = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

ax = coefs_series.plot(kind='bar')
ax.set_title('feature_coef_graph')
ax.set_xlabel('x_features')
ax.set_ylabel('coef')
ax.set_xticklabels(x_labels)
# Out:
# [Text(0, 0, 'CRIM'),
#  Text(1, 0, 'ZN'),
#  Text(2, 0, 'INDUS'),
#  Text(3, 0, 'CHAS'),
#  Text(4, 0, 'NOX'),
#  Text(5, 0, 'RM'),
#  Text(6, 0, 'AGE'),
#  Text(7, 0, 'DIS'),
#  Text(8, 0, 'RAD'),
#  Text(9, 0, 'TAX'),
#  Text(10, 0, 'PTRATIO'),
#  Text(11, 0, 'B'),
#  Text(12, 0, 'LSTAT')]

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/A202009066/anaconda3/envs/gcn/lib/python3.8/site-packages (0.12.2)
# Requirement already satisfied: scipy>=1.1 in /Users/A202009066/anaconda3/envs/gcn/lib/python3.8/site-packages (from statsmodels) (1.6.2)
# Requirement already satisfied: patsy>=0.5 in /Users/A202009066/anaconda3/envs/gcn/lib/python3.8/site-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: pandas>=0.21 in /Users/A202009066/anaconda3/envs/gcn/lib/python3.8/site-packages (from statsmodels) (1.2.4)
# Requirement already satisfied: numpy>=1.15 in /Users/A202009066/anaconda3/envs/gcn/lib/python3.8/site-packages (from statsmodels) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/A202009066/anaconda3/envs/gcn/lib/python3.8/site-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/A202009066/anaconda3/envs/gcn/lib/python3.8/site-packages (from pandas>=0.21->statsmodels) (2021.1)
# Requirement already satisfied: six in /Users/A202009066/anaconda3/envs/gcn/lib/python3.8/site-packages (from patsy>=0.5->statsmodels) (1.16.0)

# %%
import statsmodels.api as sm

X_train = sm.add_constant(X_train)
model = sm.OLS(y_train, X_train).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.749
# Model:                            OLS   Adj. R-squared:                  0.741
# Method:                 Least Squares   F-statistic:                     89.54
# Date:                Thu, 16 Sep 2021   Prob (F-statistic):          2.61e-108
# Time:                        21:04:41   Log-Likelihood:                -1196.1
# No. Observations:                 404   AIC:                             2420.
# Df Residuals:                     390   BIC:                             2476.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         22.2710      0.247     90.074      0.000      21.785      22.757
# CRIM          -0.9564      0.300     -3.192      0.002      -1.546      -0.367
# ZN             1.1881      0.353      3.362      0.001       0.493       1.883
# INDUS          0.2233      0.470      0.475      0.635      -0.701       1.148
# CHAS           3.0212      0.936      3.227      0.001       1.181       4.862
# NOX           -1.7858      0.513     -3.482      0.001      -2.794      -0.777
# RM             2.8427      0.326      8.723      0.000       2.202       3.483
# AGE           -0.0556      0.411     -0.135      0.892      -0.863       0.752
# DIS           -3.2873      0.491     -6.695      0.000      -4.253      -2.322
# RAD            2.8476      0.651      4.375      0.000       1.568       4.127
# TAX           -2.3397      0.718     -3.259      0.001      -3.751      -0.928
# PTRATIO       -1.7799      0.312     -5.700      0.000      -2.394      -1.166
# B              0.7985      0.293      2.725      0.007       0.222       1.375
# LSTAT         -4.1780      0.405    -10.317      0.000      -4.974      -3.382
# ==============================================================================
# Omnibus:                      167.528   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              769.057
# Skew:                           1.774   Prob(JB):                    1.00e-167
# Kurtosis:                       8.753   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ----
# ### 3) 예측 모델 평가하기

# %%
X = scaled_housing_df[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 
                       'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = scaled_housing_df['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=33)
lr = linear_model.LinearRegression()
model = lr.fit(X_train, y_train) # 모델 학습

# %%
print(model.score(X_train, y_train)) # train R2 score
print(model.score(X_test, y_test)) # test R2 score
# Out:
# 0.7490284664199387
# 0.700934213532155

# %%
y_predictions = lr.predict(X_train)
print(sqrt(mean_squared_error(y_train, y_predictions))) # train RMSE score

y_predictions = lr.predict(X_test)
print(sqrt(mean_squared_error(y_test, y_predictions))) # test RMSE score
# Out:
# 4.672162734008589
# 4.614951784913309

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

vif.round(1)
# Out:
#     VIF Factor features
# 0          1.8     CRIM
# 1          2.3       ZN
# 2          4.0    INDUS
# 3          1.1     CHAS
# 4          4.4      NOX
# 5          1.9       RM
# 6          3.1      AGE
# 7          4.0      DIS
# 8          7.5      RAD
# 9          9.0      TAX
# 10         1.8  PTRATIO
# 11         1.3        B
# 12         2.9    LSTAT

# %% [markdown]
# ----
# ## 5. 분석 결과의 시각화
# ### 1) 데이터셋 분리 및 전처리

# %%
X = scaled_housing_df[['CRIM', 'ZN', 'CHAS', 'NOX', 
                       'RM', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
X['LON'] = housing['LON']
X['LAT'] = housing['LAT']
y = scaled_housing_df['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=33)
X_train = X_train.drop(['LON', 'LAT'], axis=1)

# %%
# 위치 정보를 추가한 테스트 데이터셋 생성하기
lr = linear_model.LinearRegression()
model = lr.fit(X_train, y_train)
y_predictions = lr.predict(X_test.drop(['LON', 'LAT'], axis=1))
X_test['CMEDV'] = y_test
X_test = X_test.reset_index(drop=True)
X_test['y_pred'] = pd.Series(y_predictions)
X_test.head(5)
# Out:
#        CRIM       ZN  CHAS       NOX        RM       DIS       RAD       TAX  \
# 0 -0.409291 -0.48724     0  0.227006 -0.460613 -0.811196 -0.867024 -1.306758
# 1  2.491712 -0.48724     0  1.193543 -0.423608 -1.047743  1.659603  1.529413
# 2  0.399567 -0.48724     0  0.511789 -0.258511 -0.842111  1.659603  1.529413
# 3  0.733743 -0.48724     0  1.599143 -0.047870 -0.758434  1.659603  1.529413
# 4 -0.405838 -0.48724     0 -0.920756 -0.306902  0.914588 -0.752178 -1.039754
#
#     PTRATIO         B     LSTAT      LON      LAT  CMEDV     y_pred
# 0  0.297683  0.234580  0.738957 -71.0377  42.2470   20.5  20.111451
# 1  0.805778  0.440616  1.976868 -71.0326  42.2011    5.6  11.403538
# 2  0.805778 -3.879233  1.489546 -71.0619  42.1948   13.4  12.992794
# 3  0.805778  0.348825  0.530304 -71.0370  42.1840   12.6  18.462443
# 4 -0.256604  0.358355 -0.434538 -70.9675  42.3170   21.2  22.547469

# %% [markdown]
# ----
# ### 2) 집 값 정보 시각화하기

# %%
# 지도의 기준이 되는 좌표들을 정의
lon_min, lon_max = -71.45, -70.55
lat_min, lat_max = 42, 42.6

axes = X_test.plot(kind="scatter", x="LON", y="LAT",
    s=X_test['CMEDV'], label="CMEDV",
    c="CMEDV", cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=1.0, figsize=(20,16),
)
axes.set_xlim([lon_min, lon_max])
axes.set_ylim([lat_min, lat_max])
plt.legend()

fig = plt.gcf()
plt.show()
fig.savefig('CMEDV_map.png', transparent=True)

# %%
axes = X_test.plot(kind="scatter", x="LON", y="LAT",
    s=X_test['y_pred'], label="y_pred",
    c="y_pred", cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=1.0, figsize=(20,16),
)
axes.set_xlim([lon_min, lon_max])
axes.set_ylim([lat_min, lat_max])
plt.legend()

fig = plt.gcf()
plt.show()
fig.savefig('pred_map.png', transparent=True)
# Out:
# /Users/A202009066/anaconda3/envs/gcn/lib/python3.8/site-packages/matplotlib/collections.py:1003: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ----
# ### 3) 지도에 시각화하기

# %%
conda install -c conda-forge basemap
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - dglteam/osx-64::dgl==0.6.1=py38_0
#   - defaults/noarch::requests==2.25.1=pyhd3eb1b0_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/A202009066/anaconda3/envs/gcn
#
#   added / updated specs:
#     - basemap
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     basemap-1.2.2              |   py38h3cbed64_2        15.2 MB  conda-forge
#     c-ares-1.17.2              |       h0d85af4_0          96 KB  conda-forge
#     chardet-4.0.0              |   py38h50d1736_1         204 KB  conda-forge
#     geos-3.8.1                 |       h4a8c4bd_0         901 KB  conda-forge
#     kiwisolver-1.3.2           |   py38h12bbefe_0          57 KB  conda-forge
#     krb5-1.19.2                |       hcfbf3a7_0         1.3 MB  conda-forge
#     libcurl-7.79.0             |       hf45b732_0         317 KB  conda-forge
#     libcxx-12.0.1              |       habf9029_0         1.1 MB  conda-forge
#     libssh2-1.10.0             |       h52ee1ee_0         221 KB  conda-forge
#     libwebp-base-1.2.1         |       h0d85af4_0         692 KB  conda-forge
#     lz4-c-1.9.3                |       he49afe7_1         155 KB  conda-forge
#     matplotlib-base-3.4.3      |   py38hc7d2367_0         7.2 MB  conda-forge
#     openssl-1.1.1l             |       h0d85af4_0         1.9 MB  conda-forge
#     pillow-7.2.0               |   py38hef457fe_2         639 KB  conda-forge
#     proj-7.1.1                 |       h45baca5_3         2.4 MB  conda-forge
#     pyproj-2.6.1.post1         |   py38h4367d1d_3         391 KB  conda-forge
#     pyshp-2.1.3                |     pyh44b312d_0          36 KB  conda-forge
#     python-dateutil-2.8.2      |     pyhd8ed1ab_0         240 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     tornado-6.1                |   py38h96a0964_1         645 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        33.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   basemap            conda-forge/osx-64::basemap-1.2.2-py38h3cbed64_2
#   c-ares             conda-forge/osx-64::c-ares-1.17.2-h0d85af4_0
#   chardet            conda-forge/osx-64::chardet-4.0.0-py38h50d1736_1
#   cycler             conda-forge/noarch::cycler-0.10.0-py_2
#   freetype           conda-forge/osx-64::freetype-2.10.4-h4cff582_1
#   geos               conda-forge/osx-64::geos-3.8.1-h4a8c4bd_0
#   jbig               conda-forge/osx-64::jbig-2.1-h0d85af4_2003
#   jpeg               conda-forge/osx-64::jpeg-9d-hbcb3906_0
#   kiwisolver         conda-forge/osx-64::kiwisolver-1.3.2-py38h12bbefe_0
#   krb5               conda-forge/osx-64::krb5-1.19.2-hcfbf3a7_0
#   lcms2              conda-forge/osx-64::lcms2-2.12-h577c468_0
#   lerc               conda-forge/osx-64::lerc-2.2.1-h046ec9c_0
#   libcurl            conda-forge/osx-64::libcurl-7.79.0-hf45b732_0
#   libdeflate         conda-forge/osx-64::libdeflate-1.7-h35c211d_5
#   libedit            conda-forge/osx-64::libedit-3.1.20191231-h0678c8f_2
#   libev              conda-forge/osx-64::libev-4.33-haf1e3a3_1
#   libnghttp2         conda-forge/osx-64::libnghttp2-1.43.0-h07e645a_0
#   libpng             conda-forge/osx-64::libpng-1.6.37-h7cec526_2
#   libssh2            conda-forge/osx-64::libssh2-1.10.0-h52ee1ee_0
#   libtiff            conda-forge/osx-64::libtiff-4.3.0-h1167814_1
#   libwebp-base       conda-forge/osx-64::libwebp-base-1.2.1-h0d85af4_0
#   lz4-c              conda-forge/osx-64::lz4-c-1.9.3-he49afe7_1
#   matplotlib-base    conda-forge/osx-64::matplotlib-base-3.4.3-py38hc7d2367_0
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   pillow             conda-forge/osx-64::pillow-7.2.0-py38hef457fe_2
#   proj               conda-forge/osx-64::proj-7.1.1-h45baca5_3
#   pyparsing          conda-forge/noarch::pyparsing-2.4.7-pyh9f0ad1d_0
#   pyproj             conda-forge/osx-64::pyproj-2.6.1.post1-py38h4367d1d_3
#   pyshp              conda-forge/noarch::pyshp-2.1.3-pyh44b312d_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.2-pyhd8ed1ab_0
#   python_abi         conda-forge/osx-64::python_abi-3.8-2_cp38
#   tornado            conda-forge/osx-64::tornado-6.1-py38h96a0964_1
#   zstd               conda-forge/osx-64::zstd-1.5.0-h582d3a0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.5.25-~ --> conda-forge::ca-certificates-2021.5.30-h033912b_0
#   libcxx                         pkgs/main::libcxx-10.0.0-1 --> conda-forge::libcxx-12.0.1-habf9029_0
#   openssl              pkgs/main::openssl-1.1.1k-h9ed2024_0 --> conda-forge::openssl-1.1.1l-h0d85af4_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main::certifi-2021.5.30-py38hecd~ --> conda-forge::certifi-2021.5.30-py38h50d1736_0
#
#
#
# Downloading and Extracting Packages
# python-dateutil-2.8. | 240 KB    | ##################################### | 100%
# python_abi-3.8       | 4 KB      | ##################################### | 100%
# lz4-c-1.9.3          | 155 KB    | ##################################### | 100%
# geos-3.8.1           | 901 KB    | ##################################### | 100%
# libcurl-7.79.0       | 317 KB    | ##################################### | 100%
# krb5-1.19.2          | 1.3 MB    | ##################################### | 100%
# matplotlib-base-3.4. | 7.2 MB    | ##################################### | 100%
# openssl-1.1.1l       | 1.9 MB    | ##################################### | 100%
# kiwisolver-1.3.2     | 57 KB     | ##################################### | 100%
# tornado-6.1          | 645 KB    | ##################################### | 100%
# chardet-4.0.0        | 204 KB    | ##################################### | 100%
# libssh2-1.10.0       | 221 KB    | ##################################### | 100%
# pyshp-2.1.3          | 36 KB     | ##################################### | 100%
# pyproj-2.6.1.post1   | 391 KB    | ##################################### | 100%
# proj-7.1.1           | 2.4 MB    | ##################################### | 100%
# basemap-1.2.2        | 15.2 MB   | ##################################### | 100%
# libwebp-base-1.2.1   | 692 KB    | ##################################### | 100%
# libcxx-12.0.1        | 1.1 MB    | ##################################### | 100%
# pillow-7.2.0         | 639 KB    | ##################################### | 100%
# c-ares-1.17.2        | 96 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge basemap-data-hires
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/A202009066/anaconda3/envs/gcn
#
#   added / updated specs:
#     - basemap-data-hires
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     basemap-data-hires-1.2.2   |                0       105.4 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       105.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   basemap-data-hires conda-forge/osx-64::basemap-data-hires-1.2.2-0
#
#
#
# Downloading and Extracting Packages
# basemap-data-hires-1 | 105.4 MB  | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Windows :
os.environ["PROJ_LIB"] = "C:\\Utilities\\Python\Anaconda\\Library\\share"

# Mac OS, Linux :
os.environ["PROJ_LIB"] = "/anaconda3/envs/{env_name}/share/proj"

# %%
from mpl_toolkits.basemap import Basemap

# 보스턴 지도 그리기
plt.figure(2, figsize=(15, 10))

m = Basemap(projection='merc',
            llcrnrlat=lat_min,
            urcrnrlat=lat_max,
            llcrnrlon=lon_min,
            urcrnrlon=lon_max,
            lat_ts=35,
            resolution='f')

m.fillcontinents(color='white',lake_color='black')
m.drawmapboundary(fill_color='black')
m.drawcoastlines()

# 맵 이미지 저장
fig = plt.gcf()
plt.show()
fig.savefig('map.png', transparent=True)

# %%
map_img = plt.imread('map.png')
pred_img = plt.imread('CMEDV_map.png')

x_offset, y_offset = 70, 390
coord_list = [0 + x_offset, 1080 + x_offset, 720 + y_offset, 0 + y_offset]
map_ax = plt.imshow(map_img, extent=coord_list)
pred_ax = plt.imshow(pred_img)

# %%
map_img = plt.imread('map.png')
pred_img = plt.imread('pred_map.png')

x_offset, y_offset = 70, 390
coord_list = [0 + x_offset, 1080 + x_offset, 720 + y_offset, 0 + y_offset]
map_ax = plt.imshow(map_img, extent=coord_list)
pred_ax = plt.imshow(pred_img)
